# %% [markdown]
# ### Chapter 4 Exercises
# (which are actually from chapter 3)
#
#
# 2. Mentally run each of the code blocks below and write down the output
# of each code block:
#
# **a.**
# ```py
# for i in range(1, 6):
#  print(f'The cube of {i} is {i*i*i}')
# ```
# `>>> The cube of 1 is 1`
# `>>> The cube of 2 is 8`
# `>>> The cube of 3 is 27`
# `>>> The cube of 4 is 64`
# `>>> The cube of 5 is 125`
#
#
# **b.**
# ```py
# i, s = 1, 1
# while i<=10:
#  s *= i
#  i += 1
# print("the product of 1x2x3…10 is ", s)
# ```
# `>>> the product of 1x2x3…10 is 3628800`
#
# **c.**
# ```py
# total = 0
# for i in range(10):
#  total += i*2 +1
# print(f'1+3+5+ … +19 = {total}')
# ```
# `>>> 1+3+5+ … +19 = 100`
# but why is there "+19" ?
#
# **d.**
# ```py
# number = 32
# factors = []
# for d in range(1, number):
#  if number % d == 0:
#  factors += [d]
# print(f'factors of {number} are {factors}')
# ```
# `>>> Indent error, expected indented block` (I think)

# %%
# 9. In the world of science and mathematics, the existence of some
# constants has attracted the attention of many scientists and
# mathematicians. Among those constants, pi π is the most well-known.
# Many great efforts have been made to get a more precise value for π.
# The following is a formula developed by Gottfried Leibniz for the
# calculation of π.
# pi/4 = 1 - 1/3 + 1/5 - 1/7 + 1/9 - ... = sum((-1^i) / (2i + 1))
# Write a program that takes an integer from the user to specify the
# number of terms used to calculate π. Calculate and display the
# approximate value.

def Leibniz_pi(terms):
    pi = 0 # gasp
    for i in range(terms):
        pi += ((-1) ** i) / ((2 * i) + 1)
    pi *= 4

    return pi

print(f"Pi is something like {Leibniz_pi(int(input("Enter (fairly large) number of terms...")))} ish")
# Out:
# Pi is something like 3.1415914035897172 ish

# %%
# 10. Three integers—A, B and C—are called a Pythagorean (triple) when C * C =
# A * A + B * B. Write a program to take an input of integer from the
# user and find all the Pythagorean triples of integers, none of which
# are bigger than the integer taken from the user. For example, if the
# number from the user is 6, then 5, 4, and 3 are a Pythagorean triple
# because 52 = 42  + 32 = 25.

def pythrip():
    n = int(input("Input an integer (or a float and it'll get inaccurately rounded for you)..."))
    for a in range(1, n+1):
        for b in range(a, n+1):
            c_squared = (a**2 + b**2)
            c = int(c_squared ** 0.5) # result of squaring is float
            if c*c == c_squared and c <= n:
                print(a,b,c)

pythrip()
# Out:
# 3 4 5
# 5 12 13
# 6 8 10
# 7 24 25
# 8 15 17
# 9 12 15
# 12 16 20
# 15 20 25

# %%
# 11. Compound interest is a common practice in finance and banking
# to earn interest on interest as well as on the principal. Assume that
# your bank offers you a deposit account through which you can earn
# compound interest, the amount you deposit into the account is p, and
# annual compound interest is r. By the end of n years after your initial
# deposit, the account balance will be a = p(1 + r)n. For this project, get
# p, r, and n from the user, then calculate and display a table showing
# the balance, the interest earned each year, and the total interest
# earned so far.

def compound_interest(p, n, r):
    print(f"{'Year':<6} {'Balance':<12} {'Interest This Year':<20} {'Total Interest':<15}")
    total = 0
    for year in range(1, n+1):
        shoes = p * (1 + r)**year
        year_interest = shoes - p * (1 + r)**(year - 1)
        total += year_interest
        print(f"{year:<6} {shoes:<12.2f} {year_interest:<20.2f} {total:<15.2f}")


def calc_compound_interest():
    principal = float(input("Enter principal investment..."))
    years = int(input("Enter number of years invested..."))
    rate = float(input("Enter annual interest rate (as decimal, eg 5% = 0.05)..."))
    compound_interest(principal,years,rate)

calc_compound_interest()
# Out:
# Year   Balance      Interest This Year   Total Interest
# 1      64200.00     4200.00              4200.00
# 2      68694.00     4494.00              8694.00
# 3      73502.58     4808.58              13502.58
# 4      78647.76     5145.18              18647.76
# 5      84153.10     5505.34              24153.10
# 6      90043.82     5890.72              30043.82
# 7      96346.89     6303.07              36346.89
# 8      103091.17    6744.28              43091.17

# %%
# 12. An integer is called a perfect number*
#  if the sum of its factors,
# excluding itself, is equal to the integer itself. For example, 6 is a
# perfect number because 6 = 1 + 2 + 3, and 1, 2, and 3 are all its factors.
# Write a program to get a number from a user, then determine if the
# number is a perfect number. If yes, display all its factors.

def perfect_num(num=None):
    if num == None:
        num = int(input("Enter an integer..."))
    factors = []
    for n in range(1,num):
        if num % n == 0:
            factors.append(n)
    
    if sum(factors) == num:
        print(f"{num} is a perfect number. Factors: {factors}")
    else:
        print("Not a perfect number")

perfect_num()
# Out:
# 6 is a perfect number. Factors: [1, 2, 3]

# %%
# 13. For a given integer n, if another integer m can divide n, then m is
# called a factor of n. In mathematics, finding all factors of a given
# integer is an important operation, especially for cryptography. Write
# a program that takes an integer from the user and determine and
# display all the factors of the number given by the user.
# * By definition, a perfect number is a positive integer that is equal to the sum of all its divisors,
# excluding itself but including 1. The smallest perfect number is 6, which is equal to the sum of
# 1, 2, and 3.

def get_factors(num=None):
    if num == None:
        num = int(input("Enter an integer..."))
    factors = [n for n in range(1,num+1) if num % n == 0]
    print(f"factors of {num}: {factors}")

get_factors()
# Out:
# factors of 231: [1, 3, 7, 11, 21, 33, 77, 231]

# %%
# 14. Read a series of float numbers from the user and calculate and display
# the average of all the numbers given by the user. Assume that the
# number of float numbers is unknown but that a negative number is
# used to indicate the end of the input.

def avg_of_floats(floats=list()):
    if len(floats) == 0:
        while True:
            n = float(input("Enter a number (enter a negative to stop)..."))
            if n < 0:
                break
            floats.append(n)
    print(f"Avg: {sum(floats)/len(floats)}")

avg_of_floats()
# Out:
# Avg: 13.857142857142858

# %%
# 15. For a mortgage with a principal of P at a fixed monthly interest rate of
# r that needs to be paid off in Y years or 12 * Y = N months, the monthly
# payment would be:
# M = (rP(1+r)^n) / ((1+r)^n - 1)
# Continuing the project you did above for project 8, calculate a table
# showing the interest and principal paid each month and the principal
# balance at each month’s end.

def mortgage_payment_monthly(principal, annual_interest, years):
    r = annual_interest / 12 # fixed annual rate, not compounding monthly
    n = years * 12
    p = principal
    monthly_payment = (r * p * ((1 + r) ** n)) / (((1 + r) ** n) - 1 )

    print(f"Monthly payment: {monthly_payment:.2f}\n")
    print(f"{'Month':<7} {'Interest':<12} {'Principal':<12} {'Balance':<12}")

    balance = principal
    for month in range(1, n+1):
        interest = balance * r
        principal_paid = monthly_payment - interest
        balance -= principal_paid
        print(f"{month:<7} {interest:<12.2f} {principal_paid:<12.2f} {max(balance, 0):<12.2f}")


print(mortgage_payment_monthly(400000, 0.028, 30))
# Out:
# Monthly payment: 1643.58
