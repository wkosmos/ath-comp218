# %% [markdown]
# ### Exercises

# %% [markdown]
# 1. Valid python identifiers:
# - `This` valid.
# - `3da` invalid; starts with invalid char
# - `My_name` valid
# - `for` invalid; reserved keyword
# - `i9` valid
# - `vote` valid
# - `$s` invalid; starts with invalid char and contains "$"
# - `_sum_` valid
# - `cLearance` valid
# - `method` - valid
# - `lists` - valid
# - `t5#` - invalid; contains "#"

# %% [markdown]
# 2.
# a.
# ```py
# k = int(input())
# ```
#
# b.
# ```py
# print("""Simon Dawkins
# 463 Evermeadow Road SW
# Calgary, AB
# T2Y4W4""")
#
# ```
#
# c.
# ```py
# print("530.93")
# ```
#
# d.
# ```py
# x = 23**3
# ```
#
# e.
# ```py
# print(12**2, 25**2, 56**2)
# ```

# %%
# 3.
a = 23 + 16 / 2
b = round(78.3)
c = pow(2,3) + 5
d = sum([1,3,5,7,9])/13
e = bin(9)
f = divmod(13, 5)
g = int(38.6)//7
h = (3.5 + 6.7j) + (5.3 + 12.9j)
i = 'Well' * 3 + '!'

print(a,b,c,d,e,f,g,h,i)
# Out:
# 31.0 78 13 1.9230769230769231 0b1001 (2, 3) 5 (8.8+19.6j) WellWellWell!

# %% [markdown]
# 4.
# a.
# ```py
# x = 5
# y = 6
# print(x + y)
# ```
# `>>> 11`
#
# b.
# ```py
# m = 5
# k = 3
# print(f’{m}**{k} = {m**k}’)
# ```
# `>>> 5**3 = 125`
# c.
# ```py
# m, k = 35, 12
# m //= k
# print(m)
# ```
# `>>> 2
# `d.
# ```py
# m, k = 35, 12
# m %= k
# print(m)
# ```
# `>>> 1`
